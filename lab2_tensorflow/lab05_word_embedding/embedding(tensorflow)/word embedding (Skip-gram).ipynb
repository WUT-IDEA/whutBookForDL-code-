# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.
# <br>
# Adapted from https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/udacity/5_word2vec.ipynb

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import pickle
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'as', 'of', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0), name='embedding')
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                   labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 200001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset: batch_data, train_labels: batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()

    # save normalized embedding
    normalized_embeddings = session.run(normalized_embeddings)
    np.save('embedding(Skip-gram)', normalized_embeddings)
    # save dictionary of data
    with open('dictionary(Skip-gram).pkl', 'wb') as file_stream:
        pickle.dump(dictionary, file_stream)
# Out:
# Initialized
# Average loss at step 0: 7.918900
# Nearest to about: eda, hitchhikers, predated, buses, intercollegiate, incentive, commendation, eased,
# Nearest to called: publique, limburg, zemin, gideon, idempotent, doubting, el, unikom,
# Nearest to six: hardens, roach, completions, salish, strengthens, denham, warrants, rooney,
# Nearest to by: jacobs, ihr, buttstock, honneur, hagar, diamagnetic, donaldson, hypertalk,
# Nearest to nine: kocher, hymenoptera, unctad, tutored, mejid, tans, custard, anarcho,
# Nearest to world: downloaded, bench, acorn, derry, longue, davy, khoi, tabari,
# Nearest to had: samuelson, electrolysis, interred, gianfranco, broke, dumont, brockhaus, adys,
# Nearest to united: forays, arizona, herold, flavoured, wives, sq, casey, volk,
# Nearest to state: dribbling, adherence, modestly, henderson, saxony, coerced, reservoir, chojn,
# Nearest to if: pirates, lowball, villiers, sesame, perigee, relieve, pluto, ola,
# Nearest to there: plundered, heterosexuals, samuel, clashes, generations, aztlan, asp, adware,
# Nearest to has: tampere, daryl, dioscorus, quicksort, multipurpose, crystallizes, girardeau, eros,
# Nearest to a: unwritten, supervised, files, felling, ruble, h, tudes, morale,
# Nearest to known: motorcycles, geology, microclimates, gerardus, woollen, acknowledgement, jutsu, virginal,
# Nearest to american: bowing, flashlight, attractions, mineral, silence, trigonometric, selections, reuniting,
# Nearest to or: trilingual, nusa, ruptured, quadruple, pandemics, routledge, rulebook, phimosis,
# Average loss at step 2000: 4.369039
# Average loss at step 4000: 3.867820
# Average loss at step 6000: 3.790767
# Average loss at step 8000: 3.686732
# Average loss at step 10000: 3.619566
# Nearest to about: eda, studd, incentive, terrorist, subpoenaed, blog, igm, livia,
# Nearest to called: linguists, publique, cyclic, algebra, administer, kami, chernobyl, emerson,
# Nearest to six: eight, five, seven, four, three, nine, zero, two,
# Nearest to by: was, on, as, from, algonquian, after, street, chiao,
# Nearest to nine: eight, seven, six, five, zero, three, four, two,
# Nearest to world: acorn, tabari, downloaded, bench, electronegativity, south, zapu, lussac,
# Nearest to had: has, have, was, samuelson, interred, were, been, did,
# Nearest to united: retaliate, shouldn, arizona, willem, feedback, consequentialist, same, concludes,
# Nearest to state: figurines, showcase, adherence, chojn, tribulation, dribbling, antebellum, canonized,
# Nearest to if: joyous, sesame, though, sticker, pirates, kor, pagans, chievo,
# Nearest to there: it, often, he, they, which, emulated, adware, that,
# Nearest to has: had, was, is, have, eros, rode, renminbi, foiled,
# Nearest to a: the, tudes, galileo, this, overlooked, beckenbauer, mok, eruption,
# Nearest to known: jutsu, such, solf, motorcycles, geology, abort, renoir, commodus,
# Nearest to american: trigonometric, magneto, and, transitioning, attractions, rewind, northridge, nanaimo,
# Nearest to or: and, than, mortgages, s, spiracles, functionalist, personalized, bilge,
# Average loss at step 12000: 3.605239
# Average loss at step 14000: 3.577156
# Average loss at step 16000: 3.409219
# Average loss at step 18000: 3.459897
# Average loss at step 20000: 3.544372
# Nearest to about: terrorist, yonkers, studd, incentive, gamut, buses, saturdays, eda,
# Nearest to called: linguists, el, cloning, publique, cyaxares, emerson, kami, goes,
# Nearest to six: five, eight, seven, four, nine, three, two, zero,
# Nearest to by: were, algonquian, in, from, airways, was, is, tvs,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to world: acorn, downloaded, tabari, zapu, people, dusty, armistice, electronegativity,
# Nearest to had: has, have, was, were, been, samuelson, rode, did,
# Nearest to united: shouldn, arizona, retaliate, feedback, concludes, willem, consequentialist, manifestations,
# Nearest to state: figurines, sahib, antebellum, gens, showcase, adherence, decimals, chojn,
# Nearest to if: though, when, sticker, took, kor, because, nehemiah, is,
# Nearest to there: it, they, he, which, often, these, this, now,
# Nearest to has: had, was, have, is, renminbi, foiled, rode, eros,
# Nearest to a: no, the, this, beckenbauer, stink, felling, polynomials, ib,
# Nearest to known: such, jutsu, solf, venerated, geology, sassanian, motorcycles, abort,
# Nearest to american: trigonometric, magneto, alters, french, northridge, german, attractions, transitioning,
# Nearest to or: than, and, insignificance, mortgages, schiaparelli, frisians, condensation, personalized,
# Average loss at step 22000: 3.505976
# Average loss at step 24000: 3.489273
# Average loss at step 26000: 3.483435
# Average loss at step 28000: 3.483662
# Average loss at step 30000: 3.507021
# Nearest to about: yonkers, terrorist, on, gimps, studd, shoah, defensively, olav,
# Nearest to called: el, linguists, goes, cloning, polemic, oceania, cyaxares, publique,
# Nearest to six: four, seven, eight, nine, five, three, zero, two,
# Nearest to by: in, with, under, after, crypto, for, cricketers, pledge,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to world: acorn, dusty, downloaded, tabari, vietnam, follies, proponents, zapu,
# Nearest to had: have, has, was, were, did, been, renminbi, is,
# Nearest to united: arizona, shouldn, retaliate, same, feedback, southern, in, assassination,
# Nearest to state: figurines, antebellum, sloths, decimals, showcase, composition, dribbling, sahib,
# Nearest to if: when, though, because, sticker, within, where, took, is,
# Nearest to there: they, it, often, he, these, usually, which, now,
# Nearest to has: had, is, have, was, since, having, renminbi, peri,
# Nearest to a: no, tudes, any, individualists, the, pulsar, beckenbauer, galileo,
# Nearest to known: used, such, regarded, well, solf, sassanian, abort, jutsu,
# Nearest to american: english, british, canadian, magneto, german, french, mede, trigonometric,
# Nearest to or: and, bilge, reorganised, aral, spoon, without, than, serie,
# Average loss at step 32000: 3.500192
# Average loss at step 34000: 3.491135
# Average loss at step 36000: 3.454548
# Average loss at step 38000: 3.300142
# Average loss at step 40000: 3.427420
# Nearest to about: on, yonkers, over, defensively, endanger, diarrhoea, terrorist, beagles,
# Nearest to called: goes, cyclic, polemic, madero, zant, used, administer, quite,
# Nearest to six: seven, four, five, eight, three, nine, two, one,
# Nearest to by: with, unmixed, physik, as, when, crypto, bumpy, from,
# Nearest to nine: eight, seven, five, six, zero, four, one, three,
# Nearest to world: rubens, follies, zapu, vietnam, acorn, sasaki, oceans, bmj,
# Nearest to had: has, have, was, were, did, having, renminbi, rode,
# Nearest to united: feedback, retaliate, southern, shouldn, arizona, penzias, enumerates, barbara,
# Nearest to state: sloths, decimals, figurines, hippies, fractures, showcase, antebellum, dribbling,
# Nearest to if: when, though, because, cip, where, is, sticker, diocesan,
# Nearest to there: they, it, often, usually, now, he, these, which,
# Nearest to has: had, have, was, is, rode, renminbi, foiled, became,
# Nearest to a: the, another, any, beckenbauer, this, pulsar, no, elbow,
# Nearest to known: used, such, regarded, possible, available, well, jutsu, sassanian,
# Nearest to american: british, magneto, english, german, french, canadian, russian, mede,
# Nearest to or: and, than, appropriations, no, spoon, box, maa, downing,
# Average loss at step 42000: 3.439126
# Average loss at step 44000: 3.456718
# Average loss at step 46000: 3.448865
# Average loss at step 48000: 3.354375
# Average loss at step 50000: 3.382100
# Nearest to about: yonkers, approximately, terrorist, detract, on, mech, diarrhoea, endanger,
# Nearest to called: named, polemic, goes, zant, wilkinson, elevated, cyaxares, cyclic,
# Nearest to six: eight, seven, four, three, five, nine, two, one,
# Nearest to by: through, was, novum, under, tvs, vcr, crypto, dismal,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to world: zapu, vietnam, rubens, acorn, sasaki, follies, meps, pulls,
# Nearest to had: has, have, was, were, having, did, been, renminbi,
# Nearest to united: arizona, southern, shouldn, penzias, feedback, tails, retaliate, concludes,
# Nearest to state: sloths, decimals, figurines, maid, sanfl, canonized, vella, fractures,
# Nearest to if: when, though, where, because, diocesan, find, before, marquesas,
# Nearest to there: they, it, he, now, often, usually, these, who,
# Nearest to has: had, have, was, is, having, foiled, eros, manuel,
# Nearest to a: another, the, beckenbauer, no, any, irreversible, unregistered, tudes,
# Nearest to known: used, such, regarded, possible, available, well, serves, defined,
# Nearest to american: magneto, english, british, international, european, german, northridge, french,
# Nearest to or: and, than, indic, apiaceae, achill, tigre, but, bilge,
# Average loss at step 52000: 3.438335
# Average loss at step 54000: 3.425387
# Average loss at step 56000: 3.436804
# Average loss at step 58000: 3.395676
# Average loss at step 60000: 3.397890
# Nearest to about: yonkers, on, over, approximately, detract, ethelred, spokesman, sniper,
# Nearest to called: named, used, quite, polemic, zant, contradicted, goes, wilkinson,
# Nearest to six: five, four, eight, seven, three, nine, zero, two,
# Nearest to by: through, under, ihr, using, novum, ferns, bumpy, opt,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to world: vietnam, acorn, rubens, zapu, pulls, sasaki, cold, dusty,
# Nearest to had: has, have, was, were, having, did, already, took,
# Nearest to united: tails, arizona, shouldn, southern, feedback, enumerates, penzias, papacy,
# Nearest to state: decimals, government, sloths, fetching, council, liberians, city, canonized,
# Nearest to if: when, though, where, because, although, before, is, then,
# Nearest to there: they, it, now, he, this, you, often, we,
# Nearest to has: had, have, was, is, having, eros, manuel, renminbi,
# Nearest to a: the, any, another, every, stink, beckenbauer, no, tudes,
# Nearest to known: used, regarded, such, well, possible, defined, seen, available,
# Nearest to american: european, magneto, british, irish, german, english, international, northridge,
# Nearest to or: and, than, insignificance, spoon, but, juris, without, martius,
# Average loss at step 62000: 3.239470
# Average loss at step 64000: 3.253779
# Average loss at step 66000: 3.402177
# Average loss at step 68000: 3.394115
# Average loss at step 70000: 3.362064
# Nearest to about: on, over, yonkers, approximately, vig, concerning, dimensional, detract,
# Nearest to called: named, zant, contradicted, known, precedence, wilkinson, polemic, ahaz,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to by: using, through, in, prds, jacobs, grids, ifor, polling,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to world: rubens, vietnam, oceans, acorn, pulls, sasaki, severan, dusty,
# Nearest to had: has, have, was, were, having, rode, took, foiled,
# Nearest to united: feedback, arizona, supreme, tails, toed, shouldn, southeastern, enumerates,
# Nearest to state: states, decimals, government, council, city, nation, canonized, sanfl,
# Nearest to if: when, though, because, where, although, before, toe, diocesan,
# Nearest to there: they, it, now, usually, he, generally, this, often,
# Nearest to has: had, have, is, was, since, eros, having, wishful,
# Nearest to a: the, beckenbauer, another, stun, ninety, any, culloden, brazzaville,
# Nearest to known: used, regarded, such, defined, well, seen, available, viewed,
# Nearest to american: british, magneto, irish, international, english, canadian, european, northridge,
# Nearest to or: and, than, any, juris, but, indic, swings, of,
# Average loss at step 72000: 3.371950
# Average loss at step 74000: 3.347389
# Average loss at step 76000: 3.318355
# Average loss at step 78000: 3.351230
# Average loss at step 80000: 3.381585
# Nearest to about: approximately, yonkers, over, detract, loco, concerning, waking, dimensional,
# Nearest to called: named, known, used, contradicted, wilkinson, pilsner, zant, polemic,
# Nearest to six: seven, four, five, eight, three, nine, two, zero,
# Nearest to by: through, polling, jacobs, bumpy, sunsets, disband, olof, from,
# Nearest to nine: eight, seven, five, six, four, three, zero, one,
# Nearest to world: rubens, vietnam, oceans, acorn, pulls, cold, multifinder, dusty,
# Nearest to had: has, have, was, were, having, began, never, been,
# Nearest to united: arizona, tails, shouldn, supreme, feedback, southeastern, toed, penzias,
# Nearest to state: decimals, states, government, city, nation, sloths, ivanovich, territory,
# Nearest to if: when, though, where, since, because, before, although, then,
# Nearest to there: it, they, he, we, usually, she, often, now,
# Nearest to has: had, have, is, was, since, having, jamil, peri,
# Nearest to a: the, another, codename, stink, mellitus, beckenbauer, regaining, every,
# Nearest to known: used, regarded, called, defined, possible, such, seen, available,
# Nearest to american: international, british, irish, european, canadian, conductor, entire, magneto,
# Nearest to or: and, than, juris, appropriations, ordinals, while, apiaceae, xena,
# Average loss at step 82000: 3.409432
# Average loss at step 84000: 3.407783
# Average loss at step 86000: 3.394110
# Average loss at step 88000: 3.356294
# Average loss at step 90000: 3.367570
# Nearest to about: approximately, yonkers, concerning, over, detract, igf, on, waking,
# Nearest to called: named, used, known, contradicted, wilkinson, fungus, pilsner, kwajalein,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to by: through, using, olof, under, from, ferns, crypto, tvs,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to world: pulls, cold, vietnam, rubens, country, patriarch, acorn, oceans,
# Nearest to had: has, have, was, were, having, since, returned, rupiah,
# Nearest to united: supreme, arizona, tails, confederate, southeastern, shouldn, feedback, toed,
# Nearest to state: government, decimals, territory, city, nation, sloths, states, ivanovich,
# Nearest to if: when, though, where, since, before, because, after, toe,
# Nearest to there: they, it, he, we, now, usually, she, still,
# Nearest to has: had, have, is, was, since, having, includes, peri,
# Nearest to a: another, the, any, beckenbauer, ninety, lao, every, bet,
# Nearest to known: regarded, used, such, defined, seen, possible, available, described,
# Nearest to american: british, canadian, irish, international, european, english, french, german,
# Nearest to or: and, though, forbid, than, juris, duma, but, galicia,
# Average loss at step 92000: 3.397474
# Average loss at step 94000: 3.253906
# Average loss at step 96000: 3.356700
# Average loss at step 98000: 3.245281
# Average loss at step 100000: 3.356147
# Nearest to about: approximately, yonkers, concerning, on, directed, gleaming, waking, detract,
# Nearest to called: named, known, used, contradicted, higgins, airframe, referred, fungus,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to by: through, cmp, using, olof, tvs, skilling, vcr, been,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to world: country, rubens, u, pulls, patriarch, oceans, starch, drinkordie,
# Nearest to had: has, have, was, having, were, since, rupiah, would,
# Nearest to united: southeastern, tails, confederate, arizona, supreme, coast, toed, shouldn,
# Nearest to state: city, government, decimals, territory, ivanovich, sanfl, nation, council,
# Nearest to if: when, though, where, because, before, toe, so, since,
# Nearest to there: they, it, he, we, still, now, usually, she,
# Nearest to has: had, have, was, is, since, having, peri, jamil,
# Nearest to a: another, any, the, beckenbauer, galileo, elbow, pulsar, ninety,
# Nearest to known: regarded, such, defined, used, possible, seen, available, described,
# Nearest to american: british, canadian, irish, international, french, english, european, russian,
# Nearest to or: and, than, indic, juris, though, functionalist, forbid, sforza,
# Average loss at step 102000: 3.338807
# Average loss at step 104000: 3.321814
# Average loss at step 106000: 3.354499
# Average loss at step 108000: 3.346753
# Average loss at step 110000: 3.231938
# Nearest to about: approximately, over, concerning, neurotoxicity, yonkers, directed, waking, around,
# Nearest to called: named, known, used, contradicted, referred, said, considered, fungus,
# Nearest to six: seven, four, eight, five, three, nine, two, zero,
# Nearest to by: through, in, with, is, was, during, under, crypto,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to world: country, vietnam, sasaki, pulls, patriarch, cold, acorn, jumo,
# Nearest to had: has, have, was, having, were, began, subsequently, since,
# Nearest to united: toed, tails, southeastern, confederate, arizona, supreme, feedback, coast,
# Nearest to state: government, states, territory, nation, council, city, decimals, department,
# Nearest to if: when, though, where, because, toe, unless, should, then,
# Nearest to there: they, it, still, he, today, she, laude, we,
# Nearest to has: had, have, is, was, since, having, bundeswehr, jamil,
# Nearest to a: the, beckenbauer, bet, another, individualists, programmability, filaments, bethany,
# Nearest to known: regarded, defined, such, used, described, seen, called, served,
# Nearest to american: canadian, british, european, australian, irish, english, international, german,
# Nearest to or: and, though, toland, while, than, but, serpents, without,
# Average loss at step 112000: 3.265349
# Average loss at step 114000: 3.315219
# Average loss at step 116000: 3.316195
# Average loss at step 118000: 3.322806
# Average loss at step 120000: 3.311645
# Nearest to about: concerning, approximately, over, yonkers, aug, waking, detract, neurotoxicity,
# Nearest to called: named, used, contradicted, known, referred, considered, fungus, senile,
# Nearest to six: four, seven, five, eight, nine, three, two, zero,
# Nearest to by: through, from, under, with, during, was, successively, disband,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to world: earth, sasaki, patriarch, country, pulls, cold, today, rubens,
# Nearest to had: has, have, was, having, were, since, never, been,
# Nearest to united: tails, toed, southeastern, arizona, confederate, border, coast, supreme,
# Nearest to state: states, government, territory, disaster, hippies, nation, city, liberians,
# Nearest to if: when, where, since, though, before, toe, then, because,
# Nearest to there: they, it, he, she, we, still, now, today,
# Nearest to has: had, have, is, was, having, since, intoxicated, jamil,
# Nearest to a: another, the, elbow, galileo, codename, beckenbauer, this, enough,
# Nearest to known: defined, regarded, used, seen, possible, considered, called, such,
# Nearest to american: english, british, canadian, irish, european, australian, french, japanese,
# Nearest to or: and, than, juris, mortgages, without, indic, though, apiaceae,
# Average loss at step 122000: 3.318599
# Average loss at step 124000: 3.253178
# Average loss at step 126000: 3.207491
# Average loss at step 128000: 3.288907
# Average loss at step 130000: 3.202222
# Nearest to about: concerning, approximately, ethelred, than, waking, detract, yonkers, aug,
# Nearest to called: named, known, used, fungus, contradicted, referred, attained, considered,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to by: through, bumpy, with, jacobs, olof, zalta, logarithmic, crypto,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to world: nfl, drinkordie, sasaki, bovine, vietnam, patriarch, pulls, rubens,
# Nearest to had: has, have, having, was, never, were, since, rupiah,
# Nearest to united: toed, southeastern, tails, confederate, arizona, following, supreme, border,
# Nearest to state: government, nation, territory, city, council, ivanovich, states, trust,
# Nearest to if: when, where, though, because, since, before, suppose, then,
# Nearest to there: they, it, she, he, we, usually, now, still,
# Nearest to has: had, have, is, was, since, having, jamil, contains,
# Nearest to a: another, beckenbauer, every, the, galileo, any, tudes, ninety,
# Nearest to known: regarded, defined, used, seen, considered, such, possible, described,
# Nearest to american: british, canadian, english, australian, irish, german, french, russian,
# Nearest to or: and, than, juris, though, per, apiaceae, serie, functionalist,
# Average loss at step 132000: 3.242330
# Average loss at step 134000: 3.280751
# Average loss at step 136000: 3.191550
# Average loss at step 138000: 3.326978
# Average loss at step 140000: 3.304659
# Nearest to about: concerning, approximately, waking, ethelred, ur, yonkers, detract, interesting,
# Nearest to called: named, known, considered, used, dried, contradicted, fungus, referred,
# Nearest to six: seven, eight, four, nine, five, three, two, zero,
# Nearest to by: using, including, tvs, jacobs, with, cmp, regina, via,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to world: sasaki, nfl, u, drinkordie, codec, pulls, european, rubens,
# Nearest to had: has, have, having, were, was, since, never, sees,
# Nearest to united: southeastern, toed, confederate, tails, arizona, following, supreme, border,
# Nearest to state: government, states, territory, nation, council, city, disaster, impasse,
# Nearest to if: when, though, where, before, because, since, although, toe,
# Nearest to there: they, it, he, she, we, still, now, usually,
# Nearest to has: had, have, was, is, since, jamil, having, gysin,
# Nearest to a: another, beckenbauer, enough, the, stink, bethany, pulsar, quite,
# Nearest to known: regarded, defined, called, seen, such, described, considered, used,
# Nearest to american: british, australian, canadian, chilean, irish, european, english, swedish,
# Nearest to or: and, than, juris, though, but, mbe, indic, bilge,
# Average loss at step 142000: 3.273251
# Average loss at step 144000: 3.121874
# Average loss at step 146000: 3.268246
# Average loss at step 148000: 3.297638
# Average loss at step 150000: 3.305883
# Nearest to about: concerning, approximately, waking, yonkers, interesting, related, bingen, regarding,
# Nearest to called: named, known, referred, contradicted, fungus, dried, pilsner, used,
# Nearest to six: seven, five, eight, four, nine, three, two, zero,
# Nearest to by: through, using, via, jacobs, during, tvs, including, when,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to world: sasaki, nfl, pulls, earth, european, grave, u, rubens,
# Nearest to had: has, have, was, having, were, never, rupiah, since,
# Nearest to united: southeastern, confederate, tails, toed, arizona, following, remaining, border,
# Nearest to state: government, states, territory, nation, sanfl, impasse, trust, council,
# Nearest to if: when, where, though, before, because, toe, unless, since,
# Nearest to there: they, it, he, she, we, now, usually, currently,
# Nearest to has: had, have, was, is, having, since, contains, jamil,
# Nearest to a: another, beckenbauer, the, any, codename, stink, irreversible, individualists,
# Nearest to known: regarded, used, defined, called, possible, seen, serves, considered,
# Nearest to american: british, australian, canadian, european, irish, italian, chilean, english,
# Nearest to or: and, ore, than, juris, indic, functionalist, but, yaum,
# Average loss at step 152000: 3.322125
# Average loss at step 154000: 3.315142
# Average loss at step 156000: 3.286013
# Average loss at step 158000: 3.154703
# Average loss at step 160000: 3.272506
# Nearest to about: approximately, concerning, over, waking, interesting, breathtaking, regarding, olav,
# Nearest to called: named, known, contradicted, referred, dried, considered, used, pilsner,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to by: including, from, during, olof, without, through, algonquian, wanda,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to world: nfl, sasaki, pulls, vietnam, starch, drinkordie, earth, u,
# Nearest to had: has, have, having, was, were, rupiah, since, eventually,
# Nearest to united: tails, confederate, southeastern, arizona, toed, border, supreme, arab,
# Nearest to state: government, nation, territory, city, states, trust, council, sanfl,
# Nearest to if: when, though, where, toe, before, unless, because, although,
# Nearest to there: it, they, he, she, usually, currently, still, we,
# Nearest to has: had, have, is, was, having, includes, jamil, contains,
# Nearest to a: another, pohjola, the, any, beckenbauer, nazarbayev, brazzaville, bethany,
# Nearest to known: regarded, used, possible, called, defined, considered, serves, such,
# Nearest to american: canadian, british, australian, european, english, irish, italian, indian,
# Nearest to or: and, than, though, ferment, forbid, implosion, vicious, financiers,
# Average loss at step 162000: 3.338434
# Average loss at step 164000: 3.251104
# Average loss at step 166000: 3.236302
# Average loss at step 168000: 3.277893
# Average loss at step 170000: 3.266458
# Nearest to about: approximately, concerning, regarding, over, waking, interesting, aug, detract,
# Nearest to called: named, known, contradicted, referred, said, preparing, dried, considered,
# Nearest to six: eight, five, seven, nine, four, three, two, zero,
# Nearest to by: through, via, in, with, wanda, algonquian, makeover, including,
# Nearest to nine: eight, seven, six, five, four, three, two, zero,
# Nearest to world: nfl, sasaki, pulls, cold, vietnam, starch, rubens, drinkordie,
# Nearest to had: has, have, having, was, were, never, attempted, since,
# Nearest to united: confederate, tails, southeastern, arizona, arab, toed, border, remaining,
# Nearest to state: government, nation, city, territory, states, constitution, trust, council,
# Nearest to if: when, though, where, before, since, toe, suppose, although,
# Nearest to there: it, they, he, she, we, still, today, usually,
# Nearest to has: had, have, is, was, having, includes, jamil, contains,
# Nearest to a: another, beckenbauer, the, irreversible, stink, enough, codename, any,
# Nearest to known: regarded, used, called, defined, serves, possible, served, considered,
# Nearest to american: australian, british, canadian, french, irish, german, european, italian,
# Nearest to or: and, than, ore, vs, forbid, though, without, while,
# Average loss at step 172000: 3.298718
# Average loss at step 174000: 3.291741
# Average loss at step 176000: 3.252493
# Average loss at step 178000: 3.138862
# Average loss at step 180000: 3.273317
# Nearest to about: approximately, concerning, around, over, interesting, vig, regarding, waking,
# Nearest to called: named, known, dried, referred, used, contradicted, wir, pilsner,
# Nearest to six: seven, four, five, eight, three, nine, zero, two,
# Nearest to by: through, without, tvs, including, with, when, via, ashur,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to world: sasaki, nfl, pulls, rubens, u, vietnam, multifinder, country,
# Nearest to had: has, have, having, was, were, never, ever, subsequently,
# Nearest to united: tails, confederate, southeastern, arizona, toed, arab, remaining, border,
# Nearest to state: city, nation, government, trust, states, figurines, territory, antisense,
# Nearest to if: when, though, where, suppose, toe, before, because, although,
# Nearest to there: they, it, he, she, we, usually, still, typically,
# Nearest to has: had, have, is, was, having, since, frontispiece, aoc,
# Nearest to a: another, any, the, beckenbauer, every, stink, stranded, this,
# Nearest to known: regarded, possible, called, served, defined, seen, used, serves,
# Nearest to american: british, australian, canadian, french, irish, european, african, german,
# Nearest to or: and, than, though, forbid, ore, without, vs, per,
# Average loss at step 182000: 3.207478
# Average loss at step 184000: 3.257772
# Average loss at step 186000: 3.253542
# Average loss at step 188000: 3.235328
# Average loss at step 190000: 3.154715
# Nearest to about: approximately, concerning, over, around, biography, regarding, ethelred, moses,
# Nearest to called: named, contradicted, known, dried, used, referred, said, considered,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to by: through, including, when, jacobs, crypto, with, from, reflexes,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to world: sasaki, nfl, pulls, rubens, vietnam, drinkordie, radiotherapy, multifinder,
# Nearest to had: has, have, was, having, were, never, since, sees,
# Nearest to united: tails, confederate, southeastern, arizona, toed, arab, border, fray,
# Nearest to state: states, trust, city, government, nevado, nation, sanfl, territory,
# Nearest to if: though, when, although, before, where, suppose, unless, toe,
# Nearest to there: they, it, she, he, we, now, usually, sometimes,
# Nearest to has: had, have, is, having, since, was, maintains, renminbi,
# Nearest to a: another, beckenbauer, the, nazarbayev, mellitus, codename, brazzaville, stink,
# Nearest to known: regarded, possible, used, seen, such, served, defined, available,
# Nearest to american: british, australian, canadian, english, irish, german, french, italian,
# Nearest to or: and, ore, than, vs, scholastic, though, compelled, forbid,
# Average loss at step 192000: 2.634203
# Average loss at step 194000: 3.027463
# Average loss at step 196000: 2.976997
# Average loss at step 198000: 3.141951
# Average loss at step 200000: 3.206534
# Nearest to about: concerning, approximately, over, regarding, biographical, interesting, moses, around,
# Nearest to called: named, contradicted, said, referred, known, used, dried, fungus,
# Nearest to six: four, seven, five, eight, nine, three, zero, two,
# Nearest to by: through, with, jacobs, without, including, for, via, bumpy,
# Nearest to nine: eight, seven, six, four, five, three, zero, pmid,
# Nearest to world: nfl, pulls, drinkordie, rubens, vietnam, sasaki, year, starch,
# Nearest to had: has, have, having, never, was, were, already, eventually,
# Nearest to united: tails, southeastern, confederate, arizona, arab, following, usa, supreme,
# Nearest to state: states, trust, government, nation, city, sanfl, territory, department,
# Nearest to if: when, though, before, unless, toe, although, could, suppose,
# Nearest to there: it, they, she, now, he, we, still, currently,
# Nearest to has: had, have, is, was, having, maintains, since, includes,
# Nearest to a: another, the, beckenbauer, any, mellitus, this, brazzaville, every,
# Nearest to known: regarded, used, possible, seen, serves, served, defined, remembered,
# Nearest to american: british, english, australian, canadian, irish, italian, european, german,
# Nearest to or: and, than, nor, without, though, ore, forbid, scholastic,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y, color='b')
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
